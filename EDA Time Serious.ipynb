# %% [markdown]
# ### Importing Library

# %%
#pip install pandas-datareader

# %%
#pip install yfinance

# %%
#Data Manipulation 
#=====================================
import pandas as pd 
import numpy as np 
import pandas_datareader as pdr 
import yfinance as yf
#Data Visualization  
#=====================================
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
#Date time
#=====================================
from datetime import datetime

# %% [markdown]
# ### Read The Data

# %%
#df_tesla = pdr.get_data_yahoo('TSLA')
df_tesla=yf.download('TSLA')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %% [markdown]
# ### See The Plot Of the Data Volume has a Highest value

# %%
df_tesla.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
### Xlimit and y Limit
df_tesla['High'].plot(xlim=['2020-01-01','2024-09-01'],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].plot(xlim=['2020-01-01','2024-09-01'],ylim=[0,900],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].plot(xlim=['2020-01-01','2024-09-01'],ylim=[0,900],figsize=(12,4),ls='--',color='green')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-06-18', '2024-06-20', '2024-06-21', '2024-06-24',
#                '2024-06-25', '2024-06-26', '2024-06-27', '2024-06-28',
#                '2024-07-01', '2024-07-02'],
#               dtype='datetime64[ns]', name='Date', length=3526, freq=None)

# %%
index=df_tesla.loc['2020-01-01': '2024-09-01'].index
share_price_open=df_tesla.loc['2020-01-01': '2024-09-01']['Open']

# %%
share_price_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2024-06-26    186.539993
# 2024-06-27    195.169998
# 2024-06-28    199.550003
# 2024-07-01    201.020004
# 2024-07-02    218.889999
# Name: Open, Length: 1132, dtype: float64

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2024-06-18', '2024-06-20', '2024-06-21', '2024-06-24',
#                '2024-06-25', '2024-06-26', '2024-06-27', '2024-06-28',
#                '2024-07-01', '2024-07-02'],
#               dtype='datetime64[ns]', name='Date', length=1132, freq=None)

# %%
figure,axis=plt.subplots()
plt.tight_layout()
## Preventing Overlapping 
figure.autofmt_xdate()
axis.plot(index,share_price_open)

# %% [markdown]
# ### Datetime Index

# %%
df_tesla=df_tesla.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3526 entries, 0 to 3525
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3526 non-null   datetime64[ns]
#  1   Open       3526 non-null   float64
#  2   High       3526 non-null   float64
#  3   Low        3526 non-null   float64
#  4   Close      3526 non-null   float64
#  5   Adj Close  3526 non-null   float64
#  6   Volume     3526 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 193.0 KB

# %%
pd.to_datetime(df_tesla['Date'])
# Out:
# 0      2010-06-29
# 1      2010-06-30
# 2      2010-07-01
# 3      2010-07-02
# 4      2010-07-06
#           ...
# 3521   2024-06-26
# 3522   2024-06-27
# 3523   2024-06-28
# 3524   2024-07-01
# 3525   2024-07-02
# Name: Date, Length: 3526, dtype: datetime64[ns]

# %%
df_tesla=df_tesla.set_index('Date',drop=True)

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %% [markdown]
# ### Datetime

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 7, 3, 16, 28, 49, 133817)

# %%
date=datetime(2021,11,21)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
# def add_number(num1,num2):
#     return num1+num2

# starttime=datetime.now()
# num1=20
# num2=30
# for i in [1,2,3,4,5]:
#     add_number(num1,num2)
# endtime=datetime.now()
# print(endtime-starttime)

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %%
date.hour
# Out:
# 0

# %%
date.month
# Out:
# 11

# %% [markdown]
# ### Time Resampling

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
df_tesla.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
df_tesla.resample(rule='A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-31    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-31   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
type(df_tesla.resample(rule='A').max())
# Out:
# pandas.core.frame.DataFrame

# %%
### Year And Frequancy 
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
### Quaterly start Frequancy
df_tesla.resample(rule='QS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.719333    2.028000    1.553333    1.592667    1.592667
# 2010-07-01    1.666667    1.728000    1.408667    1.465333    1.465333
# 2010-10-01    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-01-01    1.906000    1.914000    1.870000    1.896667    1.896667
# 2011-04-01    2.006667    2.100000    1.970000    2.009333    2.009333
# 2011-07-01    1.992667    2.029333    1.934000    1.982000    1.982000
# 2011-10-01    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-01-01    2.546000    2.663333    2.474000    2.529333    2.529333
# 2012-04-01    2.488667    2.564667    2.444667    2.534000    2.534000
# 2012-07-01    2.333333    2.400000    2.260000    2.397333    2.397333
# 2012-10-01    2.350667    2.386667    2.330000    2.352000    2.352000
# 2013-01-01    2.630000    2.666667    2.609333    2.632000    2.632000
# ...

# %%
df_tesla.resample(rule='QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
### Business End Frequency 
df_tesla.resample(rule='BA').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-30    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-30   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-29   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
### Business Quarters
df_tesla.resample(rule='BQS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.719333    2.028000    1.553333    1.592667    1.592667
# 2010-07-01    1.666667    1.728000    1.408667    1.465333    1.465333
# 2010-10-01    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-01-03    1.906000    1.914000    1.870000    1.896667    1.896667
# 2011-04-01    2.006667    2.100000    1.970000    2.009333    2.009333
# 2011-07-01    1.992667    2.029333    1.934000    1.982000    1.982000
# 2011-10-03    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-01-02    2.546000    2.663333    2.474000    2.529333    2.529333
# 2012-04-02    2.488667    2.564667    2.444667    2.534000    2.534000
# 2012-07-02    2.333333    2.400000    2.260000    2.397333    2.397333
# 2012-10-01    2.350667    2.386667    2.330000    2.352000    2.352000
# 2013-01-01    2.630000    2.666667    2.609333    2.632000    2.632000
# ...

# %%
df_tesla['Open'].resample(rule='BA').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='A').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
## Monthly 
monthly_max = df_tesla['Open'].resample('M').max()


fig, ax = plt.subplots(figsize=(20, 8))
monthly_max.plot(kind='bar', ax=ax)
ax.set_xticklabels(monthly_max.index.strftime('%b %Y'))

plt.show()

# %%
df_tesla['High'].head()
# Out:
# Date
# 2010-06-29    1.666667
# 2010-06-30    2.028000
# 2010-07-01    1.728000
# 2010-07-02    1.540000
# 2010-07-06    1.333333
# Name: High, dtype: float64

# %% [markdown]
# ### Rolling Function

# %%
df_tesla['High'].rolling(11).mean().head(20)
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# 2010-07-07         NaN
# 2010-07-08         NaN
# 2010-07-09         NaN
# 2010-07-12         NaN
# 2010-07-13         NaN
# 2010-07-14    1.414242
# 2010-07-15    1.393030
# 2010-07-16    1.337758
# 2010-07-19    1.315515
# 2010-07-20    1.307939
# 2010-07-21    1.313394
# 2010-07-22    1.341394
# 2010-07-23    1.365879
# 2010-07-26    1.387697
# 2010-07-27    1.406545
# Name: High, dtype: float64

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %% [markdown]
# ### Create New Columns

# %%
df_tesla['Open:30 days rolling']=df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#             Open:30 days rolling
# Date
# 2010-06-29                   NaN
# 2010-06-30                   NaN
# 2010-07-01                   NaN
# 2010-07-02                   NaN
# 2010-07-06                   NaN

# %%
df_tesla[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ##Assignment
# ##news
# 1. Read the Microsoft Data using Pandas Data reader
# 2. Get the maximum price of the share from 2017 to 2022
# 3. Which is the date of the highest price of the stock?
# 4. Which is the date of the lowest price of the stock?
